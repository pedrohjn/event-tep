# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from glob import glob
import datetime

# %%
paths = glob('d*_te.dat')
plt.figure(figsize=(14,5))
original = {}
columns_name = range(1,53)
for mov in range(0,22):
    data = np.genfromtxt(paths[mov])
    original[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(original[2].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - Original Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_Orig_file')
plt.show()

pathsm = glob('NEW_5_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 5% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_5%_Compressed_file')
plt.show()

pathsm = glob('NEW_10_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 10% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_10%_Compressed_file')
plt.show()

pathsm = glob('NEW_20_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 20% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_20%_Compressed_file')
plt.show()

pathsm = glob('NEW_30_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 30% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_30%_Compressed_file')
plt.show()

pathsm = glob('NEW_40_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 40% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_40%_Compressed_file')
plt.show()

pathsm = glob('NEW_50_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 50% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_50%_Compressed_file')
plt.show()

pathsm = glob('NEW_60_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 60% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_60%_Compressed_file')
plt.show()

pathsm = glob('NEW_70_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 70% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_70%_Compressed_file')
plt.show()

pathsm = glob('NEW_80_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 80% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_80%_Compressed_file')
plt.show()

pathsm = glob('NEW_90_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 90% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_90%_Compressed_file')
plt.show()

pathsm = glob('NEW_95_d*_te.dat')
plt.figure(figsize=(14,5))
modified = {}
columns_name = range(1,53)
for mov in range(1,len(pathsm)):
    data = np.genfromtxt(pathsm[mov])
    modified[mov] = pd.DataFrame(data=data,columns=columns_name)    
plt.plot(modified[1].iloc[:,0],'k')
plt.grid()
plt.suptitle('Fault 1 - 95% Compressed Data', fontsize=14)
plt.ylim(0.1,0.4)
plt.savefig('Fault_1_95%_Compressed_file')
plt.show()
